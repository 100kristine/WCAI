# %%
from __future__ import division
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from gensim import corpora
import gensim,re
from collections import defaultdict,Counter

# %%
#Files
d = "line_item_purchase/"
f1 = "line_1_KC_only.txt"
f2 = "line_2_KC_only.txt"
f3 = "test2.txt"
pdef = "product.txt"

# %%
#Visualize
def load_Frame(f):
    x = pd.DataFrame.from_csv(d+f,header=0,sep="|",index_col=3)
    x.sort(['hh_id','trans_date','trans_time'])            
    return x
#wcai_sample_group = Known Consumer (KC), Known Professionals (KP), and Randomly Selected Customers (ALL)
load_Frame(f1)
# Out:
#              hh_id wcai_sample_group  cust_segment  loc_id  register_id  \
# channel
# STORE    378038094                KC             3     411           97
# STORE    443916448                KC             3    2409           56
# STORE    389209180                KC             3    1348           25
# STORE    381217935                KC             3    1564           57
# STORE    389249168                KC             3     958           11
# STORE    408482884                KC             3     487           40
# STORE    431644138                KC             3     951           56
# STORE    398292622                KC             3    2848           58
# STORE    430680223                KC             3     442            9
# STORE    378335496                KC             3    1900           10
# STORE    422243937                KC             3     313            3
# STORE    397135902                KC             3     526           19
# STORE    460516011                KC             3     980           58
# STORE    408262579                KC             3     441            2
# STORE    638699400                KC             3    1058           16
# STORE    417134553                KC             3     686           57
# STORE    438225429                KC             3     673            4
# STORE    393145851                KC             3    1289           57
# STORE    442210237                KC             3     320           18
# STORE    417839652                KC             3    2696            1
# STORE    390718863                KC             3     799            6
# STORE    384363566                KC             3    1367           23
# STORE    482049503                KC             3    1517           18
# STORE    381936385                KC             3    2087           57
# STORE    404363358                KC             3    2019           56
# STORE    406274672                KC             3     906           56
# STORE    673211924                KC             3     589           59
# STORE    560055487                KC             3    2233           57
# STORE    497253957                KC             3     759           56
# STORE    414646161                KC             3    1205           56
# ...            ...               ...           ...     ...          ...
# STORE    404164919                KC             3    1944            1
# STORE    638441275                KC             3    1632           59
# STORE    414191226                KC             3     956           21
# STORE    435630887                KC             3    2708            5
# STORE    385330429                KC             3    2197           58
# STORE    428209952                KC             3    1649           58
# STORE    390572330                KC             3     897           13
# STORE    380208566                KC             3     660           13
# STORE    438262575                KC             3    1507            9
# STORE    425322188                KC             3    1363           24
# STORE    383670186                KC             3    1143           21
# STORE    429240027                KC             3    1659           10
# STORE    607771023                KC             3    2083           57
# STORE    498364760                KC             3    1148           59
# STORE    387302922                KC             3     480            2
# STORE    418821530                KC             3    2731            1
# STORE    393318071                KC             3    1117           57
# STORE    560291899                KC             3    2044            2
# STORE    443379886                KC             3     898           97
# STORE    404251990                KC             3     530            5
# STORE    378171700                KC             3     705           27
# STORE    420495132                KC             3    1251           57
# STORE    586888123                KC             3     490           21
# STORE    405133538                KC             3     403           56
# STORE    437113480                KC             3     799           58
# STORE    395356580                KC             3    1710           19
# STORE    407211826                KC             3     388           27
# STORE    442048136                KC             3    2229            6
# STORE    382871948                KC             3    1344           59
# STORE    383464481                KC             3     456           57
#
#         trans_date trans_time  item_id  unit_qty  unit_sales  \
# channel
# STORE    18FEB2014   12:37:40    94202         1        9.99
# STORE    11JAN2014   12:59:34   386795         2        9.92
# STORE    02JUL2012   16:43:45   446600         2       10.94
# STORE    25MAY2013   16:48:09    32272         1        5.97
# STORE    01DEC2013   15:11:44   285394         1        4.18
# STORE    18JUN2012   11:59:26   814541         1        9.97
# STORE    11AUG2012   10:09:59   165796         1        2.99
# STORE    04APR2013   13:51:18   604767         2        5.94
# STORE    01FEB2014   08:42:34   272523         1       13.25
# STORE    13APR2012   12:07:56   273437         1       19.86
# STORE    01JUL2013   13:40:03   799758         1       50.00
# STORE    18JAN2013   10:38:25   379946        40       67.20
# STORE    14NOV2012   12:28:13   333150         1        1.97
# STORE    28MAY2012   14:32:15   682114         6      114.00
# STORE    05DEC2012   17:24:26    70329         1        0.49
# STORE    30NOV2013   09:47:39  2424515         1        4.99
# STORE    24NOV2013   16:02:15     2777         1        7.98
# STORE    03SEP2013   07:31:40  2251282         1        1.18
# STORE    31MAY2013   19:41:39   660289        -1      -74.97
# STORE    21MAY2012   20:18:29   751609         1        4.20
# STORE    21APR2012   12:50:38   551943         1      149.00
# STORE    23FEB2014   12:10:47   557180         2       19.94
# STORE    23NOV2013   10:01:57   824258         3       62.02
# STORE    17MAY2013   09:11:45   775133         1        9.98
# STORE    08JUN2012   12:58:47   314349         4        2.72
# STORE    10MAR2012   11:53:42   800671         1        3.57
# STORE    08APR2013   16:58:02   476616         4       23.92
# STORE    11FEB2014   14:17:28    23594         1       13.48
# STORE    17JUL2012   14:14:11   456109         1       12.59
# STORE    22APR2013   15:36:01   565312         1       19.92
# ...            ...        ...      ...       ...         ...
# STORE    24JUN2013   12:51:44    34652         1       18.97
# STORE    07AUG2013   15:34:24    37042         1       16.98
# STORE    11SEP2012   17:10:13   727957         2       27.90
# STORE    14MAR2012   09:55:54   820560         2       58.76
# STORE    01SEP2012   14:36:19    22545         1       12.99
# STORE    30JUN2013   15:16:29   791153         1        5.97
# STORE    01DEC2013   13:19:41   767254        14      111.72
# STORE    21AUG2013   19:05:03   197945         1       17.97
# STORE    13APR2013   16:31:43   822055         1        9.68
# STORE    21APR2013   14:16:28   436499        -1       -1.98
# STORE    19FEB2013   12:28:35   778318        -1      -10.98
# STORE    15DEC2012   10:47:02   779340         1        3.87
# STORE    28MAR2013   15:27:34   794013         1        8.97
# STORE    04APR2012   19:48:43   820539         1       29.38
# STORE    11MAY2013   16:40:22  2326352         5        0.10
# STORE    06FEB2013   10:33:18   356376         1        5.82
# STORE    29JUN2012   09:18:42   409847         1        2.87
# STORE    16MAY2012   10:57:53   337584         1        3.28
# STORE    03JUL2012   11:58:30   298624         1       84.87
# STORE    05DEC2013   11:50:17   755630         1       29.97
# STORE    17JUN2013   18:34:06   533527        -1       -4.17
# STORE    19FEB2014   11:04:58    36499         1       20.98
# STORE    12NOV2012   12:24:14   433945         2       25.98
# STORE    07APR2013   11:39:44   453573         1        1.98
# STORE    04DEC2012   10:15:02    40781         2        5.16
# STORE    19OCT2013   13:40:59   783290        -2      -10.94
# STORE    24JUN2013   14:20:29   661275         2        5.34
# STORE    15JUN2013   16:46:41   424180         1        6.87
# STORE    26AUG2013   15:20:17    75340         1       19.88
# STORE    14MAR2013   13:11:29  2261457         2       39.94
#
#          unit_discount_pro_rewards  unit_discount_pro_paint  \
# channel
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# ...                            ...                      ...
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
# STORE                            0                        0
#
#          unit_discount"vpp  unit_discount_ivp  unit_discount_lowes  \
# channel
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# ...                    ...                ...                  ...
# STORE                    0                  0                   -1
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
# STORE                    0                  0                    0
#
#          unit_discount_military  unit_discount_all_other  wcai_gross_sales
# channel
# STORE                      0.00                     0.00              9.99
# STORE                      0.00                     0.00              9.92
# STORE                      0.00                     0.00             10.94
# STORE                      0.00                     0.00              5.97
# STORE                      0.00                     0.00              4.18
# STORE                      0.00                     0.00              9.97
# STORE                      0.00                     0.00              2.99
# STORE                      0.00                     0.00              5.94
# STORE                      0.00                     0.00             13.25
# STORE                      0.00                     0.00             19.86
# STORE                      0.00                     0.00             50.00
# STORE                      0.00                     0.00             67.20
# STORE                      0.00                     0.00              1.97
# STORE                      0.00                     0.00            114.00
# STORE                      0.00                     0.00              0.49
# STORE                      0.00                     0.00              4.99
# STORE                      0.00                     0.00              7.98
# STORE                      0.00                     0.00              1.18
# STORE                      0.00                     0.00            -74.97
# STORE                      0.00                     0.00              4.20
# STORE                      0.00                     0.00            149.00
# STORE                      0.00                     0.00             19.94
# STORE                     -6.89                     0.00             55.13
# STORE                      0.00                     0.00              9.98
# STORE                      0.00                     0.00              2.72
# STORE                      0.00                     0.00              3.57
# STORE                      0.00                     0.00             23.92
# STORE                      0.00                     0.00             13.48
# STORE                      0.00                     0.00             12.59
# STORE                      0.00                     0.00             19.92
# ...                         ...                      ...               ...
# STORE                      0.00                     0.00             17.97
# STORE                      0.00                     0.00             16.98
# STORE                      0.00                     0.00             27.90
# STORE                      0.00                     0.00             58.76
# STORE                      0.00                     0.00             12.99
# STORE                      0.00                     0.00              5.97
# STORE                      0.00                     0.00            111.72
# STORE                     -2.00                     0.00             15.97
# STORE                      0.00                     0.00              9.68
# STORE                      0.00                     0.00             -1.98
# STORE                      0.00                     0.00            -10.98
# STORE                      0.00                     0.00              3.87
# STORE                      0.00                     0.00              8.97
# STORE                      0.00                     0.00             29.38
# STORE                      0.00                     0.00              0.10
# STORE                     -0.65                     0.00              5.17
# STORE                      0.00                     0.00              2.87
# STORE                      0.00                     0.00              3.28
# STORE                      0.00                   -15.08             69.79
# STORE                      0.00                     0.00             29.97
# STORE                      0.00                     0.00             -4.17
# STORE                      0.00                     0.00             20.98
# STORE                      0.00                     0.00             25.98
# STORE                      0.00                     0.00              1.98
# STORE                      0.00                     0.00              5.16
# STORE                      0.00                     0.00            -10.94
# STORE                      0.00                     0.00              5.34
# STORE                      0.00                     0.00              6.87
# STORE                      0.00                     0.00             19.88
# STORE                      0.00                     0.00             39.94
#
# [839645 rows x 18 columns]

# %%
def group_By_Household_Unanamed(df):
    #Return dictionary of lines grouped by household ids, does not convert product names
    ids = list(set(df['hh_id']))
    dct = {}
    for iden in ids:
        dct[iden] = df[df['hh_id']==iden]['item_id'].values
    return dct

exclude = ['AMERIGAS.EMPTY.PROPANE.TANK.EXCHANGE',
 '40.LB.TOPSOIL',
 'E/O.BONNIE.ECO.PREM.PEATVEG.HERB.5IN',
 '2X4-96".PREMIUM.KD.WHITEWOOD.STUD',
 '5GAL.HOMER.BUCKET',
 '9.IN.PLASTIC.TRAY.LINER.-.WHITE',
 '1.CU.FT.MG.FLOWER.&.VEG.GARDEN.SOIL',
 'PLASTIC.BAG.GOODS',
 'E/O.VEGETABLE.PEAT.POT.RED.5IN',
 '30GAL.PAPER.LAWN.BAGS-5PK',
 '1/2"X260".PTFE.THRD.SEAL.TAPE',
 '66.KEY.KWIKSET',
 'SCOTCH.BLUE.1.88".PAINTERS.2090',
 '1.25.CU.FT.MIRACLE.GRO.POTTING.MIX',
 'CHIP.2.0.FLAT.BRUSH',
 'E/O.ECO.VEG.4.IN.PEAT.SHORT',
 '16OZ.GAPS.&.CRACKS.GREAT.STUFF',
 'ENERGIZER.AA.36-PACK',
 'BETTER.9.IN.TRAY.SET.-.8.PIECE',
 '2.CU.FT.SCOTTS.EARTHGRO.BRN.MULCH',
 '42GAL.3MIL.CONTRACTOR.TRASHBAG.32PK',
 'ES.14W.DAYLIGHT.SPIRAL.BULB.4PK',
 '0.75.CU.FT.SCOTTS.PREMIUM.TOPSOIL',
 '2.CU.FT.CYPRESS.MULCH',
 'SCRIPTO.AIM.N.FLAME..II.LIGHTER']

# %%
len(exclude)
# Out:
# 25

# %% [markdown]
# Load product definitions (condense convenience and cards.rentals items)
#
# Alternate version of product definitions - use this if we want to get rid of the high frequency items. Uncomment to revert to original.

# %%
def load_product_def(pname):
    #load conversions for product table
    #Altered to group subcategories
    dct = defaultdict()
    
    with open(pname) as f:
        next(f)
        for line in f:
            line = line.split("|")
            #if line[5] == "CONVENIENCE":#Added to consolidate
            #    pass
                #dct[line[0]] = ["CONVENIENCE"]
            #elif re.match(r"""[0-9\-]+""",line[3]):
            #    pass
                #dct[line[0]] = ["CARDS.RENTALS"]
            #else:
                #print dct[line[0]]
            dct[line[0]] = [".".join(line[1].split(" "))]
    return dct



pnames = load_product_def(pdef)
print len(pnames.keys())
print len(exclude)
# Out:
# 111916
# 25

# %%
def cleanDct(dct,exclude):
    exclude = set(exclude) #exclude some of the most common
    for key in dct.keys():
        if dct[key][0] in exclude:
            del dct[key]
    return dct

newPnames = cleanDct(pnames,exclude)
print len(newPnames)
# Out:
# 111891

# %% [markdown]
# Function groups together all household ids. get Date will include a tuple of (item name, date).

# %%
def group_by_household(fname,d,pnames,getDate=False):
    all_households = defaultdict(list)
    names = set(pnames.keys())
    with open(d+fname) as f:
        header = next(f).split('|')
        hh_id,item_id,date = header.index('hh_id'),header.index('item_id'),header.index('trans_date')
        for line in f:
            line = line.split('|')
            if not getDate and (line[item_id] in names):                
                all_households[line[hh_id]] +=[pnames[line[item_id]][0].decode('latin-1').encode('utf-8')]
            elif (line[item_id] in names):
                all_households[line[hh_id]] +=[(pnames[line[item_id]][0].decode('latin-1').encode('utf-8'),line[date])]
            else:
                pass
    return all_households

# %%
dct1 = group_by_household(f1,d,pnames,getDate=False)#newPnames,getDate=False)

# %%
def make_documents(dct,concatDate=False):
    keys = list(dct.keys())
    print len(keys)
    return [dct[key] for key in keys],keys

# %%
documents,household_keys = make_documents(dct1)
documents[2]
dictionary = corpora.Dictionary(documents)
corpus = [dictionary.doc2bow(text) for text in documents]
# Out:
# 19991

# %%
#lda = gensim.models.ldamodel.LdaModel(corpus=corpus,id2word=dictionary,num_topics=50,chunksize=1000,passes=50)

# %%
def runLDA(corpus,dictionary,numtopics,chunksize,passes):
    lda = gensim.models.ldamodel.LdaModel(corpus=corpus,id2word=dictionary,num_topics=numtopics,chunksize=chunksize,passes=passes)
    lda.save("LDA_"+ str(numtopics) + "_topics_" + str(chunksize) + "_chunks_" + str(passes) + "_passes.txt")
    return lda

# %%
runLDA(corpus,dictionary,470,chunksize=2000,passes=10) #9:24 - 42

# %%
runLDA(corpus,dictionary,480,chunksize=2000,passes=10) #9:24 - 42

# %%
runLDA(corpus,dictionary,490,chunksize=2000,passes=10) #9:24 - 42

# %%
runLDA(corpus,dictionary,510,chunksize=2000,passes=10) 9:50

# %%
runLDA(corpus,dictionary,520,chunksize=2000,passes=10)

# %%
runLDA(corpus,dictionary,530,chunksize=2000,passes=10)
print "start: 1:25"
#finished - 7:20?
# Out:
# start: 1:25

# %%
runLDA(corpus,dictionary,540,chunksize=2000,passes=20)

# %%
runLDA(corpus,dictionary,500,chunksize=2000,passes=10)

# %%
lda10 = gensim.models.ldamodel.LdaModel(corpus=corpus,id2word=dictionary,num_topics=10,chunksize=10000,passes=10)

# %%
# histogram of items (also quantity)
# look for sticky items
# HD has no bev category - check product table (sub class)
# can also try the subcategory level
# Home depot book - lists ()
# Precision/recall for clusters
# Look at timing - (time separation)
# Intersection - how many people get the exact same thing
# How many documents discuss this topic and how comprehensive is it?
# How many topics does this stretch across and how close the sentences are -- [histogram - % of documents ]

# Topics - by number of sentences , by close together
# By seasonality - run LDA - Sun/Spring/ - 
# Homeowners, season, how far apart in time? (different measures of purity, can )
# Time vs sentences (20k households) - look at by cluster

# %%
from nltk.tokenize import regexp_tokenize
import re
regexp_tokenize(topics[0],pattern='[0-9.*]+[a-s]')

# %%
def getSentences(topic):
    #Returns list of readable sentences
    return [re.sub("[0-9*]+",'',sentence).strip("\"'.") for sentence in topic.split(" + ")]

# %%
re.match(r"""[0-9\-]+""","017-001-004")

# %% [markdown]
# **Visualization**

# %%
dct2 =group_by_household(f1,d,pnames,getDate=True)

# %%
# Per topic
# Each data point belongs to a household
# average distance between items by household
# Fraction of sentences in that household

def getSentenceFraction(topic,dct):
    fractions,distances,households = [],[],[]
    sentences = set(getSentences(topic))
    for household in dct.keys():
        intersect = set([item[0] for item in dct2[household]]) & sentences
       
        if len(intersect) != 0:
            fractions.append(len(intersect)/len(sentences))
            households.append(household)
            distances.append(timeDistance(intersect,household,dct2))
    return fractions,households,distances

def parseDate(date):
        return datetime.datetime.strptime(date,"%d%b%Y")

def averageTimes(times):
        averageTimes = []
        i =0
        if len(times)==1:
            return 0
        else:
            while (i+1) < len(times):
                averageTimes.append(times[i+1]-times[i])
                i+=1
        return sum([t.days for t in averageTimes])/len(averageTimes)
    
def timeDistance(intersect,householdID,dct):
    #Get total time
    times = [parseDate(item[1]) for item in dct[householdID] if item[0] in intersect]
    times.sort()
    return averageTimes(times)#(times[-1]-times[0]).days

# %%
fractions,households,distances = getSentenceFraction(topics[0],dct2)

# %%
def visualize_topic(topic,dct):
    # For a particular topic, create charts to show the clustering of sentences
    # time vs sentences
    fractions,households,distances = getSentenceFraction(topic,dct)
    plt.scatter(distances,fractions,alpha=0.5)
    plt.ylabel("Fraction of items contained within topic")
    plt.xlabel("Average purchasing time between items")
    plt.show()
    return

# %%
#for i in topics10[0:10]:
#    visualize_topic(i,dct2)

# %%
for i in topics50[0:10]:
    visualize_topic(i,dct2)

# %%
for i in topics100[0:10]:
    visualize_topic(i,dct2)

# %%
for i in topics1000[0:10]:
    visualize_topic(i,dct2)

# %%
#Frequencies of items, make histogram
#Try at basket level instead of items?
#how many households at each level? could be more descriptive
#Time between - far part (# sentences per basket)


#2.) Basket (Y = time between baskets), (X= of sentences per basket)

#1.) of items vs number of baskets (if simple market basket analysis is working well)

#Remove (check product table for subclasses, see if there is one for food/beverages and remove) (?) -
#Customer purchases/category, purchases/ item
#Try heatmap instead of plot (showing) or combine
#Try LDA at subclass level 
#Instead of average time - try median (if that doesn't work as well), screen off high end 
#Get descriptive statistics - average basket size, average num items/basket, average time/purchases
#Join current product table- with the current purchase table
#Rerun LDA at this level/
