# %%
import itertools
import sys
import time

# %% [markdown]
# **http://importantfish.com/learning-association-rules-with-python/**
#
# Code adapted from above source, doesn't seem to be a built in model

# %%
def tokenize(file_name):
    # Assumes that sentences are separated by a single '\n'.
    # Assumes that words are separated by a single ' '.
    # Tokenizes each sentence, removes duplicate tokens, sorts tokens.
    return [sorted(list(set(e.split('\t')))) for e in
            open(file_name).read().strip().split('\n')]
 
def frequent_itemsets(sentences):
    # Counts sets with Apriori algorithm.
    SUPP_THRESHOLD = 30
    supps = []
 
    supp = {}
    for sentence in sentences:
        for key in sentence:
            if key in supp:
                supp[key] += 1
            else:
                supp[key] = 1
    print "|C1| = " + str(len(supp))
    supps.append({k:v for k,v in supp.iteritems() if v >= SUPP_THRESHOLD})
    print "|L1| = " + str(len(supps[0]))
 
    supp = {}
    for sentence in sentences:
        for combination in itertools.combinations(sentence, 2):
            if combination[0] in supps[0] and combination[1] in supps[0]:
                key = ','.join(combination)
                if key in supp:
                    supp[key] += 1
                else:
                    supp[key] = 1
    print "|C2| = " + str(len(supp))
    supps.append({k:v for k,v in supp.iteritems() if v >= SUPP_THRESHOLD})
    print "|L2| = " + str(len(supps[1]))
 
    supp = {}
    for sentence in sentences:
        for combination in itertools.combinations(sentence, 3):
            if (combination[0]+','+combination[1] in supps[1] and
                    combination[0]+','+combination[2] in supps[1] and
                    combination[1]+','+combination[2] in supps[1]):
                key = ','.join(combination)
                if key in supp:
                    supp[key] += 1
                else:
                    supp[key] = 1
    print "|C3| = " + str(len(supp))
    supps.append({k:v for k,v in supp.iteritems() if v >= SUPP_THRESHOLD})
    print "|L3| = " + str(len(supps[2]))
 
    return supps
 
def measures(supp_ab, supp_a, supp_b, transaction_count):
    # Assumes A -> B, where A and B are sets.
    conf = float(supp_ab) / float(supp_a)
    s = float(supp_b) / float(transaction_count)
    lift = conf / s
    if conf == 1.0:
        conv = float('inf')
    else:
        conv = (1-s) / (1-conf)
    return [conf, lift, conv]
 
def generate_rules(measure, supps, transaction_count):
    rules = []
    CONF_THRESHOLD = 0.30
    LIFT_THRESHOLD = 10.0
    CONV_THRESHOLD = 1.0
    if measure == 'conf':
        for i in range(2, len(supps)+1):
            for k,v in supps[i-1].iteritems():
                k = k.split(',')
                for j in range(1, len(k)):
                    for a in itertools.combinations(k, j):
                        b = tuple([w for w in k if w not in a])
                        [conf, lift, conv] = measures(v,
                                supps[len(a)-1][','.join(a)],
                                supps[len(b)-1][','.join(b)],
                                transaction_count)
                        if conf >= CONF_THRESHOLD:
                            rules.append((a, b, conf, lift, conv))
            rules = sorted(rules, key=lambda x: (x[0], x[1]))
            rules = sorted(rules, key=lambda x: (x[2]), reverse=True)
    elif measure == 'lift':
        for i in range(2, len(supps)+1):
            for k,v in supps[i-1].iteritems():
                k = k.split(',')
                for j in range(1, len(k)):
                    for a in itertools.combinations(k, j):
                        b = tuple([w for w in k if w not in a])
                        [conf, lift, conv] = measures(v,
                                supps[len(a)-1][','.join(a)],
                                supps[len(b)-1][','.join(b)],
                                transaction_count)
                        if lift >= LIFT_THRESHOLD:
                            rules.append((a, b, conf, lift, conv))
            rules = sorted(rules, key=lambda x: (x[0], x[1]))
            rules = sorted(rules, key=lambda x: (x[3]), reverse=True)
    elif measure == 'conv':
        for i in range(2, len(supps)+1):
            for k,v in supps[i-1].iteritems():
                k = k.split(',')
                for j in range(1, len(k)):
                    for a in itertools.combinations(k, j):
                        b = tuple([w for w in k if w not in a])
                        [conf, lift, conv] = measures(v,
                                supps[len(a)-1][','.join(a)],
                                supps[len(b)-1][','.join(b)],
                                transaction_count)
                        if conv >= CONV_THRESHOLD:
                            rules.append((a, b, conf, lift, conv))
            rules = sorted(rules, key=lambda x: (x[0], x[1]))
            rules = sorted(rules, key=lambda x: (x[4]), reverse=True)
    else:
        for i in range(2, len(supps)+1):
            for k,v in supps[i-1].iteritems():
                k = k.split(',')
                for j in range(1, len(k)):
                    for a in itertools.combinations(k, j):
                        b = tuple([w for w in k if w not in a])
                        [conf, lift, conv] = measures(v,
                                supps[len(a)-1][','.join(a)],
                                supps[len(b)-1][','.join(b)],
                                transaction_count)
                        if (conf >= CONF_THRESHOLD and
                                lift >= LIFT_THRESHOLD and
                                conv >= CONV_THRESHOLD):
                            rules.append((a, b, conf, lift, conv))
            rules = sorted(rules, key=lambda x: (x[0], x[1]))
            rules = sorted(rules, key=lambda x: (x[2],x[3],x[4]), reverse=True)
    return rules
 
def main():
    if len(sys.argv) < 2:
        sys.stderr.write("Usage: python a_priori.py"
                         "transactions.txt [measure]\n")
        sys.exit(1)
    elif len(sys.argv) == 2 or sys.argv[2] not in ['conf', 'lift', 'conv']:
        measure = 'all'
    else:
        measure = sys.argv[2]
 
    sentences = tokenize('7daybaskets.txt')
 
    start_time = time.time()
    supps = frequent_itemsets(sentences)
    end_time = time.time()
    print "Time spent finding frequent itemsets = {:.2f} seconds.".format(
          end_time - start_time)
 
    start_time = time.time()
    rules = generate_rules(measure, supps, len(sentences))
    for rule in rules:
        print ("{{{}}} -> {{{}}}, "
               "conf = {:.2f}, lift = {:.2f}, conv = {:.2f}").format(
              ', '.join(rule[0]), ', '.join(rule[1]), rule[2], rule[3], rule[4])
    end_time = time.time()
    print "Time spent finding association rules = {:.2f} second.".format(
          end_time - start_time)

# %%
main()
# Out:
# |C1| = 64746
# |L1| = 5009
# |C2| = 660928
# |L2| = 542
# |C3| = 413
# |L3| = 42
# Time spent finding frequent itemsets = 7.63 seconds.
# {M921.DISHWASHER.INSTALL, M936-DISHWASHER.110V.CORD} -> {M939-DISHWASHER.INST.KIT.&.ADAPTER}, conf = 0.98, lift = 882.03, conv = 65.93
# {M920.GAS.RANGE.INSTALL} -> {M937-GAS.RANGE.INSTALL.-.KIT.ONLY}, conf = 0.96, lift = 2261.75, conv = 22.49
# {M926.GAS.DRYER.INSTALL} -> {M938-GAS.DRYER.INSTALL.-.KIT.ONLY}, conf = 0.95, lift = 3082.14, conv = 19.49
# {M921.DISHWASHER.INSTALL} -> {M939-DISHWASHER.INST.KIT.&.ADAPTER}, conf = 0.94, lift = 845.84, conv = 17.98
# {M916.SEMI-RIGD.DRYER.DUCT, M926.GAS.DRYER.INSTALL} -> {M938-GAS.DRYER.INSTALL.-.KIT.ONLY}, conf = 0.94, lift = 3063.10, conv = 17.49
# {M936-DISHWASHER.110V.CORD} -> {M939-DISHWASHER.INST.KIT.&.ADAPTER}, conf = 0.92, lift = 823.95, conv = 12.49
# {M925-2.UPGRADE.STNLESS.WASHER.HOSE, M934-DRYER.POWER.CORD} -> {M916.SEMI-RIGD.DRYER.DUCT}, conf = 0.91, lift = 697.55, conv = 11.56
# {M926.GAS.DRYER.INSTALL} -> {M916.SEMI-RIGD.DRYER.DUCT}, conf = 0.90, lift = 685.22, conv = 9.74
# {M926.GAS.DRYER.INSTALL, M938-GAS.DRYER.INSTALL.-.KIT.ONLY} -> {M916.SEMI-RIGD.DRYER.DUCT}, conf = 0.89, lift = 680.99, conv = 9.24
# {LARGE.BOX.18"X18"X24", SMALL.BOX.16"X12"X12"} -> {MEDIUM.BOX.18"X18"X16}, conf = 0.86, lift = 241.20, conv = 6.92
# {LARGE.BOX.18"X18"X24", SCOTCH.MOVING.&.STORAGE.TAPE.W/.DISP} -> {MEDIUM.BOX.18"X18"X16}, conf = 0.85, lift = 238.90, conv = 6.55
# {M926.GAS.DRYER.INSTALL} -> {M916.SEMI-RIGD.DRYER.DUCT, M938-GAS.DRYER.INSTALL.-.KIT.ONLY}, conf = 0.85, lift = 3419.41, conv = 6.50
# {SCOTCH.MOVING.&.STORAGE.TAPE.3PK, SMALL.BOX.16"X12"X12"} -> {MEDIUM.BOX.18"X18"X16}, conf = 0.84, lift = 237.95, conv = 6.41
# {M916.SEMI-RIGD.DRYER.DUCT, M925-2.UPGRADE.STNLESS.WASHER.HOSE} -> {M934-DRYER.POWER.CORD}, conf = 0.84, lift = 700.13, conv = 6.28
# {5GAL.HOMER.LEAKPROOF.LID} -> {5GAL.HOMER.BUCKET}, conf = 0.84, lift = 122.62, conv = 6.15
# {M934-DRYER.POWER.CORD} -> {M916.SEMI-RIGD.DRYER.DUCT}, conf = 0.83, lift = 636.91, conv = 6.02
# {24"X24".70-SHEET.PACKING.PAPER, LARGE.BOX.18"X18"X24"} -> {MEDIUM.BOX.18"X18"X16}, conf = 0.83, lift = 232.58, conv = 5.71
# {PAD.NIKE.STEP.AHEAD-NAT} -> {CARPET-NAT}, conf = 0.82, lift = 395.22, conv = 5.49
# {24"X24".70-SHEET.PACKING.PAPER, SMALL.BOX.16"X12"X12"} -> {MEDIUM.BOX.18"X18"X16}, conf = 0.81, lift = 227.34, conv = 5.16
# {M916.SEMI-RIGD.DRYER.DUCT, M938-GAS.DRYER.INSTALL.-.KIT.ONLY} -> {M926.GAS.DRYER.INSTALL}, conf = 0.80, lift = 3419.41, conv = 5.12
# {M938-GAS.DRYER.INSTALL.-.KIT.ONLY} -> {M916.SEMI-RIGD.DRYER.DUCT}, conf = 0.80, lift = 613.82, conv = 5.09
# {LARGE.BOX.18"X18"X24", SCOTCH.MOVING.&.STORAGE.TAPE.3PK} -> {MEDIUM.BOX.18"X18"X16}, conf = 0.79, lift = 222.80, conv = 4.76
# {SCOTCH.MOVING.&.STORAGE.TAPE.W/.DISP, SMALL.BOX.16"X12"X12"} -> {MEDIUM.BOX.18"X18"X16}, conf = 0.79, lift = 222.46, conv = 4.73
# {5".ALUMINUM.RIGHT.END.CAP-WHITE} -> {5".ALUMINUM.LEFT.END.CAP-WHITE}, conf = 0.78, lift = 2918.33, conv = 4.44
# {VINYL.K-STYLE.HIDDEN.HOOK.-WHITE} -> {10'.K-STYLE.VINYL.GUTTER.-WHITE}, conf = 0.77, lift = 3186.27, conv = 4.33
# {M916.SEMI-RIGD.DRYER.DUCT} -> {M934-DRYER.POWER.CORD}, conf = 0.76, lift = 636.91, conv = 4.25
# {10'.K-STYLE.VINYL.GUTTER.-WHITE} -> {VINYL.K-STYLE.HIDDEN.HOOK.-WHITE}, conf = 0.75, lift = 3186.27, conv = 4.00
# {CONVENIENCE, SMALL.BOX.16"X12"X12"} -> {MEDIUM.BOX.18"X18"X16}, conf = 0.73, lift = 206.18, conv = 3.71
# {M938-GAS.DRYER.INSTALL.-.KIT.ONLY} -> {M926.GAS.DRYER.INSTALL}, conf = 0.73, lift = 3082.14, conv = 3.64
# {3/4".PVC.MALE.ADAPTER.SXMPT, 3/4".PVC.TEE.SXSXS} -> {3/4".PVC.EL.90D.SXS}, conf = 0.72, lift = 404.91, conv = 3.58
# {1G.WHT.MIDWAY.SWITCH.WALLPLT, 2G.WHT.MIDWAY.SWITCH.WALLPLT} -> {1G.WHT.NYL.MIDWAY.OUTLET.WALLPLT}, conf = 0.71, lift = 281.87, conv = 3.45
# {5GAL.HOMER.BUCKET.LIDS} -> {5GAL.HOMER.BUCKET}, conf = 0.71, lift = 103.95, conv = 3.43
# {M936-DISHWASHER.110V.CORD, M939-DISHWASHER.INST.KIT.&.ADAPTER} -> {M921.DISHWASHER.INSTALL}, conf = 0.71, lift = 929.05, conv = 3.40
# {MOVING.&STORAGE.TAPE.1.88X109, SMALL.BOX.16"X12"X12"} -> {MEDIUM.BOX.18"X18"X16}, conf = 0.71, lift = 198.90, conv = 3.39
# {5".ALUMINUM.LEFT.END.CAP-WHITE} -> {5".ALUMINUM.RIGHT.END.CAP-WHITE}, conf = 0.70, lift = 2918.33, conv = 3.38
# {E/O.ECO.VEG.4.IN.PEAT.SHORT, VEGETABLE.PEAT.POT.GROWUMS.4IN} -> {E/O.VEGETABLE.PEAT.POT.RED.5IN}, conf = 0.70, lift = 121.12, conv = 3.33
# {4X4-8FT.PT.BROWN.HEM.FIR} -> {CARDS.RENTALS}, conf = 0.69, lift = 13.04, conv = 3.05
# {ELBOW.1/2".SCH40.90DEG.BELL.END} -> {1/2.SCHEDULE.40.X.10.FT}, conf = 0.68, lift = 1118.92, conv = 3.08
# {3/4".PVC.COUPLING.SXS, 3/4".PVC.TEE.SXSXS} -> {3/4".PVC.EL.90D.SXS}, conf = 0.68, lift = 379.29, conv = 3.07
# {1".PVC.TEE.SXSXS, 1X10.PVC40.PE.PIPE} -> {1".PVC.EL.90D.SXS}, conf = 0.67, lift = 697.86, conv = 3.06
# {15A.SP.WHT.SWITCH.10PK} -> {15A.WHT.NYLON.DUPLEX.OUTLET.10PK}, conf = 0.67, lift = 987.47, conv = 3.06
# {24"X24".70-SHEET.PACKING.PAPER, MEDIUM.BOX.18"X18"X16} -> {SMALL.BOX.16"X12"X12"}, conf = 0.67, lift = 240.73, conv = 3.02
# {M936-DISHWASHER.110V.CORD} -> {M921.DISHWASHER.INSTALL}, conf = 0.66, lift = 867.88, conv = 2.94
# {BEHR.PPUI.200.UPW.SAMPLE.8OZ, BEHR.PPUI.203.DEEP.SAMPLE.8OZ} -> {BEHR.PPUI.204.MEDIUM.SAMPLE.8OZ}, conf = 0.66, lift = 238.39, conv = 2.91
# {SMALL.BOX.16"X12"X12"} -> {MEDIUM.BOX.18"X18"X16}, conf = 0.65, lift = 183.98, conv = 2.87
# {COUPLING.1/2"} -> {ELBOW.1/2".SCH40.90DEG.BELL.END}, conf = 0.65, lift = 1403.33, conv = 2.87
# {COUPLING.1/2"} -> {1/2.SCHEDULE.40.X.10.FT}, conf = 0.65, lift = 1080.56, conv = 2.87
# {M936-DISHWASHER.110V.CORD} -> {M921.DISHWASHER.INSTALL, M939-DISHWASHER.INST.KIT.&.ADAPTER}, conf = 0.65, lift = 905.01, conv = 2.86
# {M938-GAS.DRYER.INSTALL.-.KIT.ONLY} -> {M916.SEMI-RIGD.DRYER.DUCT, M926.GAS.DRYER.INSTALL}, conf = 0.65, lift = 3063.10, conv = 2.83
# {M939-DISHWASHER.INST.KIT.&.ADAPTER} -> {M921.DISHWASHER.INSTALL}, conf = 0.64, lift = 845.84, conv = 2.80
# {3/4".PVC.COUPLING.SXS, 3/4.X.10.PVC40.PE.PIPE} -> {3/4".PVC.EL.90D.SXS}, conf = 0.63, lift = 355.71, conv = 2.72
# {E/O.BONNIE.ECO.PREM.PEATVEG.HERB.5IN, VEGETABLE.PEAT.POT.GROWUMS.4IN} -> {E/O.ECO.VEG.4.IN.PEAT.SHORT}, conf = 0.63, lift = 134.39, conv = 2.71
# {E/O.BONNIE.ECO.PREM.PEATVEG.HERB.5IN, VEGETABLE.PEAT.POT.GROWUMS.4IN} -> {E/O.VEGETABLE.PEAT.POT.RED.5IN}, conf = 0.63, lift = 109.19, conv = 2.71
# {FOAM.1.0.WOOD.HANDLE.BRUSH, FOAM.3.0.WOOD.HANDLE.BRUSH} -> {FOAM.2.0.WOOD.HANDLE.BRUSH}, conf = 0.62, lift = 214.40, conv = 2.66
# {E/O.VEGETABLE.PEAT.POT.RED.5IN, VEGETABLE.PEAT.POT.GROWUMS.4IN} -> {E/O.ECO.VEG.4.IN.PEAT.SHORT}, conf = 0.62, lift = 132.76, conv = 2.65
# {60".SHELFTRACK.STANDARD} -> {12".SHELF.TRACK.BRACKET}, conf = 0.62, lift = 648.82, conv = 2.65
# {ELBOW.3/4".SCH40.90DEG.BELL.END} -> {3/4.SCHEDULE.40.X.10.FT}, conf = 0.62, lift = 1311.99, conv = 2.61
# {M937-GAS.RANGE.INSTALL.-.KIT.ONLY} -> {M920.GAS.RANGE.INSTALL}, conf = 0.61, lift = 2261.75, conv = 2.59
# {MEDIUM.BOX.18"X18"X16, SCOTCH.MOVING.&.STORAGE.TAPE.3PK} -> {SMALL.BOX.16"X12"X12"}, conf = 0.61, lift = 220.28, conv = 2.58
# {1/2".PVC.TEE.SXSXS, 1/2.X10.PVC40.PE.PIPE} -> {1/2".PVC.EL.90D.SXS}, conf = 0.61, lift = 579.66, conv = 2.58
# {LARGE.BOX.18"X18"X24", MOVING.&STORAGE.TAPE.1.88X109} -> {MEDIUM.BOX.18"X18"X16}, conf = 0.61, lift = 171.08, conv = 2.54
# {3/4".PVC.TEE.SXSXS, 3/4.X.10.PVC40.PE.PIPE} -> {3/4".PVC.EL.90D.SXS}, conf = 0.60, lift = 338.64, conv = 2.51
# {E/O.ECO.VEG.4.IN.PEAT.SHORT, E/O.HERBS.1G.FIBER.POT.GREEN.BONNIE} -> {E/O.BONNIE.ECO.PREM.PEATVEG.HERB.5IN}, conf = 0.60, lift = 76.41, conv = 2.46
# {HEX.NUT.GALV..1/2} -> {FLAT.CUT.WASHER.GALV..1/2}, conf = 0.60, lift = 1452.56, conv = 2.48
# {1".PVC.EL.90D.SXS, 1".PVC.TEE.SXSXS} -> {1X10.PVC40.PE.PIPE}, conf = 0.60, lift = 690.73, conv = 2.47
# {E/O.HERBS.1G.FIBER.POT.GREEN.BONNIE, E/O.VEGETABLE.PEAT.POT.RED.5IN} -> {E/O.BONNIE.ECO.PREM.PEATVEG.HERB.5IN}, conf = 0.59, lift = 75.76, conv = 2.43
# {LARGE.BOX.18"X18"X24"} -> {MEDIUM.BOX.18"X18"X16}, conf = 0.59, lift = 165.05, conv = 2.41
# {QT.3.X.1/4.IN.TINY.TOUCH.UP.REFILL.-} -> {QT.3.X.1/4IN.TINY.TOUCH.UP.KIT.WOVEN}, conf = 0.58, lift = 886.70, conv = 2.40
# {HEX.NUT.GALV..3/8} -> {FLAT.CUT.WASHER.GALV..3/8}, conf = 0.58, lift = 1204.99, conv = 2.39
# {E/O.VEGETABLE.PEAT.POT.RED.5IN, VEGETABLE.VINES.4IN.(14.6OZ).PEAT} -> {E/O.ECO.VEG.4.IN.PEAT.SHORT}, conf = 0.58, lift = 123.59, conv = 2.38
# {MEDIUM.BOX.18"X18"X16, SCOTCH.MOVING.&.STORAGE.TAPE.W/.DISP} -> {SMALL.BOX.16"X12"X12"}, conf = 0.58, lift = 207.35, conv = 2.36
# {2X4-8FT.PT.BROWN.HEM.FIR} -> {CARDS.RENTALS}, conf = 0.58, lift = 10.90, conv = 2.24
# {E/O.BONNIE.ECO.PREM.PEATVEG.HERB.5IN, VEGETABLE.VINES.4IN.(14.6OZ).PEAT} -> {E/O.ECO.VEG.4.IN.PEAT.SHORT}, conf = 0.57, lift = 120.69, conv = 2.30
# {E/O.HERBS.1G.FIBER.POT.GREEN.BONNIE, VEGETABLE.VINES.4IN.(14.6OZ).PEAT} -> {E/O.BONNIE.ECO.PREM.PEATVEG.HERB.5IN}, conf = 0.57, lift = 72.42, conv = 2.29
# {1G.WHT.NYL.MIDWAY.OUTLET.WALLPLT, 2G.WHT.MIDWAY.SWITCH.WALLPLT} -> {1G.WHT.MIDWAY.SWITCH.WALLPLT}, conf = 0.56, lift = 424.73, conv = 2.28
# {2X4-92.1/4".GREEN.DOUG.FIR.STUD} -> {CARDS.RENTALS}, conf = 0.56, lift = 10.55, conv = 2.14
# {24"X24".70-SHEET.PACKING.PAPER, LARGE.BOX.18"X18"X24"} -> {SMALL.BOX.16"X12"X12"}, conf = 0.56, lift = 199.67, conv = 2.24
# {RESTORE.10X.4G} -> {RESTORE.9.IN.ROLLER.COVER}, conf = 0.55, lift = 1411.76, conv = 2.24
# {RESTORE.9.IN.ROLLER.COVER} -> {RESTORE.10X.4G}, conf = 0.55, lift = 1411.76, conv = 2.24
# {3/4".PVC.EL.90D.SXS, 3/4".PVC.TEE.SXSXS} -> {3/4".PVC.COUPLING.SXS}, conf = 0.55, lift = 236.23, conv = 2.23
# {E/O.ECO.VEG.4.IN.PEAT.SHORT, VEGETABLE.VINES.4IN.(14.6OZ).PEAT} -> {E/O.VEGETABLE.PEAT.POT.RED.5IN}, conf = 0.55, lift = 95.22, conv = 2.22
# {MEDIUM.BOX.18"X18"X16, SCOTCH.MOVING.&.STORAGE.TAPE.3PK} -> {LARGE.BOX.18"X18"X24"}, conf = 0.55, lift = 239.74, conv = 2.21
# {1".PVC.TEE.SXSXS} -> {1".PVC.EL.90D.SXS}, conf = 0.55, lift = 566.82, conv = 2.21
# {M921.DISHWASHER.INSTALL, M939-DISHWASHER.INST.KIT.&.ADAPTER} -> {M936-DISHWASHER.110V.CORD}, conf = 0.55, lift = 905.01, conv = 2.20
# {E/O.ECO.VEG.4.IN.PEAT.SHORT, VEGETABLE.PEAT.POT.GROWUMS.4IN} -> {E/O.BONNIE.ECO.PREM.PEATVEG.HERB.5IN}, conf = 0.54, lift = 69.58, conv = 2.18
# {1-1/2".PVC.TEE.SXSXS} -> {1-1/2X10.PVC40.PE.SOLIDCORE.PIPE}, conf = 0.54, lift = 465.72, conv = 2.17
# {3/4.SCHEDULE.40.X.10.FT} -> {ELBOW.3/4".SCH40.90DEG.BELL.END}, conf = 0.54, lift = 1311.99, conv = 2.17
# {3/4".PVC.EL.90D.SXS, 3/4.X.10.PVC40.PE.PIPE} -> {3/4".PVC.COUPLING.SXS}, conf = 0.54, lift = 229.63, conv = 2.16
# {1/2".PVC.EL.90D.SXS, 1/2".PVC.TEE.SXSXS} -> {1/2.X10.PVC40.PE.PIPE}, conf = 0.54, lift = 424.69, conv = 2.15
# {1".PVC.EL.90D.SXS, 1X10.PVC40.PE.PIPE} -> {1".PVC.TEE.SXSXS}, conf = 0.53, lift = 932.17, conv = 2.15
# {4'X12".SUPERSLIDE.LINEN.SHELVING} -> {12".SHELF.TRACK.BRACKET}, conf = 0.53, lift = 553.59, conv = 2.13
# {E/O.BONNIE.ECO.PREM.PEATVEG.HERB.5IN, VEGETABLE.VINES.4IN.(14.6OZ).PEAT} -> {E/O.VEGETABLE.PEAT.POT.RED.5IN}, conf = 0.53, lift = 91.52, conv = 2.12
# {M921.DISHWASHER.INSTALL} -> {M936-DISHWASHER.110V.CORD}, conf = 0.52, lift = 867.88, conv = 2.10
# {6'X12".SUPERSLIDE.LINEN.SHELVING} -> {12".SHELF.TRACK.BRACKET}, conf = 0.52, lift = 545.84, conv = 2.10
# {3/4".PVC.TEE.SXSXS} -> {3/4".PVC.EL.90D.SXS}, conf = 0.52, lift = 293.30, conv = 2.09
# {1/2.SCHEDULE.40.X.10.FT} -> {ELBOW.1/2".SCH40.90DEG.BELL.END}, conf = 0.52, lift = 1118.92, conv = 2.08
# {3/4".PVC.EL.90D.SXS} -> {3/4".PVC.COUPLING.SXS}, conf = 0.52, lift = 221.47, conv = 2.07
# {DIABLO.220GRIT.CORNER.CAT/MOUSE.SHTS} -> {DIABLO.80.GRIT.CORNER.CAT/MOUSE.SHTS}, conf = 0.52, lift = 799.21, conv = 2.07
# {M921.DISHWASHER.INSTALL} -> {M936-DISHWASHER.110V.CORD, M939-DISHWASHER.INST.KIT.&.ADAPTER}, conf = 0.52, lift = 929.05, conv = 2.06
# {30".SHELFTRACK.STANDARD} -> {12".SHELF.TRACK.BRACKET}, conf = 0.52, lift = 537.31, conv = 2.06
# {M925-2.UPGRADE.STNLESS.WASHER.HOSE} -> {M916.SEMI-RIGD.DRYER.DUCT}, conf = 0.51, lift = 392.93, conv = 2.06
# {MEDIUM.BOX.18"X18"X16} -> {SMALL.BOX.16"X12"X12"}, conf = 0.51, lift = 183.98, conv = 2.04
# {DIABLO.120GRIT.CORNER.CAT/MOUSE.SHTS} -> {DIABLO.80.GRIT.CORNER.CAT/MOUSE.SHTS}, conf = 0.51, lift = 792.24, conv = 2.05
# {1/2".PVC.TEE.SXSXS} -> {1/2".PVC.EL.90D.SXS}, conf = 0.51, lift = 482.00, conv = 2.03
# {50'.DISH.FOAM.ROLL} -> {MEDIUM.BOX.18"X18"X16}, conf = 0.51, lift = 142.82, conv = 2.02
# {FEIT.13W.GREEN.TWIST.CFL.BULB} -> {FEIT.13W.RED.TWIST.CFL.BULB}, conf = 0.51, lift = 963.97, conv = 2.02
# {24"X24".70-SHEET.PACKING.PAPER} -> {MEDIUM.BOX.18"X18"X16}, conf = 0.50, lift = 141.56, conv = 2.00
# {MEDIUM.BOX.18"X18"X16, SCOTCH.MOVING.&.STORAGE.TAPE.W/.DISP} -> {LARGE.BOX.18"X18"X24"}, conf = 0.50, lift = 218.58, conv = 2.00
# {3/4".PVC.EL.90D.SXS, 3/4".PVC.MALE.ADAPTER.SXMPT} -> {3/4".PVC.COUPLING.SXS}, conf = 0.50, lift = 213.51, conv = 2.00
# {VEGETABLE.PEPPER.12.04.PK-BP} -> {E/O.ECO.VEG.4.IN.PEAT.SHORT}, conf = 0.50, lift = 106.21, conv = 1.99
# {E/O.ECO.VEG.4.IN.PEAT.SHORT, E/O.HERBS.1G.FIBER.POT.GREEN.BONNIE} -> {E/O.VEGETABLE.PEAT.POT.RED.5IN}, conf = 0.50, lift = 86.29, conv = 1.99
# {M939-DISHWASHER.INST.KIT.&.ADAPTER} -> {M936-DISHWASHER.110V.CORD}, conf = 0.50, lift = 823.95, conv = 1.99
# {E/O.BONNIE.ECO.PREM.PEATVEG.HERB.5IN, E/O.ECO.VEG.4.IN.PEAT.SHORT} -> {E/O.VEGETABLE.PEAT.POT.RED.5IN}, conf = 0.49, lift = 85.36, conv = 1.97
# {1".PVC.EL.90D.SXS} -> {1".PVC.COUPLING.SXS}, conf = 0.49, lift = 366.85, conv = 1.97
# {VEGETABLE.PEAT.POT.GROWUMS.4IN} -> {E/O.VEGETABLE.PEAT.POT.RED.5IN}, conf = 0.49, lift = 84.97, conv = 1.96
# {24"X24".70-SHEET.PACKING.PAPER, MEDIUM.BOX.18"X18"X16} -> {LARGE.BOX.18"X18"X24"}, conf = 0.49, lift = 214.46, conv = 1.96
# {1G.WHT.MIDWAY.SWITCH.WALLPLT} -> {1G.WHT.NYL.MIDWAY.OUTLET.WALLPLT}, conf = 0.49, lift = 193.66, conv = 1.95
# {SCOTCH.MOVING.&.STORAGE.TAPE.3PK} -> {MEDIUM.BOX.18"X18"X16}, conf = 0.49, lift = 137.56, conv = 1.95
# {MEDIUM.BOX.18"X18"X16, MOVING.&STORAGE.TAPE.1.88X109} -> {SMALL.BOX.16"X12"X12"}, conf = 0.49, lift = 174.85, conv = 1.94
# {E/O.VEGETABLE.PEAT.POT.RED.5IN, VEGETABLE.PEAT.POT.GROWUMS.4IN} -> {E/O.BONNIE.ECO.PREM.PEATVEG.HERB.5IN}, conf = 0.48, lift = 61.97, conv = 1.92
# {1".PVC.TEE.SXSXS} -> {1X10.PVC40.PE.PIPE}, conf = 0.48, lift = 561.03, conv = 1.94
# {HEX.NUTS-USS.1/2} -> {CUT.WASHERS.1/2.IN}, conf = 0.48, lift = 833.86, conv = 1.93
# {LARGE.BOX.18"X18"X24", MEDIUM.BOX.18"X18"X16} -> {SMALL.BOX.16"X12"X12"}, conf = 0.48, lift = 173.23, conv = 1.93
# {SCOTCH.MOVING.&.STORAGE.TAPE.W/.DISP} -> {MEDIUM.BOX.18"X18"X16}, conf = 0.48, lift = 134.84, conv = 1.91
# {CONVENIENCE, MEDIUM.BOX.18"X18"X16} -> {SMALL.BOX.16"X12"X12"}, conf = 0.48, lift = 171.15, conv = 1.90
# {E/O.ECO.VEG.4.IN.PEAT.SHORT, E/O.VEGETABLE.1G.FIBER.POT.RED.BONN} -> {E/O.BONNIE.ECO.PREM.PEATVEG.HERB.5IN}, conf = 0.48, lift = 60.93, conv = 1.89
# {M925-2.UPGRADE.STNLESS.WASHER.HOSE} -> {M934-DRYER.POWER.CORD}, conf = 0.47, lift = 394.39, conv = 1.90
# {E/O.HERBS.1G.FIBER.POT.GREEN.BONNIE, E/O.VEGETABLE.PEAT.POT.RED.5IN} -> {E/O.ECO.VEG.4.IN.PEAT.SHORT}, conf = 0.47, lift = 100.62, conv = 1.89
# {FEIT.13W.RED.TWIST.CFL.BULB} -> {FEIT.13W.GREEN.TWIST.CFL.BULB}, conf = 0.47, lift = 963.97, conv = 1.89
# {E/O.VEGETABLE.1G.FIBER.POT.RED.BONN, VEGETABLE.VINES.4IN.(14.6OZ).PEAT} -> {E/O.ECO.VEG.4.IN.PEAT.SHORT}, conf = 0.47, lift = 99.57, conv = 1.87
# {CUT.WASHERS.3/8.IN} -> {HEX.NUTS-USS.3/8}, conf = 0.46, lift = 480.05, conv = 1.86
# {2G.WHT.MIDWAY.SWITCH.WALLPLT} -> {1G.WHT.NYL.MIDWAY.OUTLET.WALLPLT}, conf = 0.46, lift = 182.21, conv = 1.85
# {MEDIUM.BOX.18"X18"X16, MOVING.&STORAGE.TAPE.1.88X109} -> {LARGE.BOX.18"X18"X24"}, conf = 0.46, lift = 200.86, conv = 1.85
# {E/O.BONNIE.ECO.PREM.PEATVEG.HERB.5IN, E/O.VEGETABLE.PEAT.POT.RED.5IN} -> {E/O.ECO.VEG.4.IN.PEAT.SHORT}, conf = 0.46, lift = 97.33, conv = 1.84
# {1G.WHT.SWITCH.WALLPLT} -> {1G.WHT.DUPLEX.WALLPLT}, conf = 0.46, lift = 272.02, conv = 1.84
# {FLAT.CUT.WASHER.GALV..1/2} -> {HEX.NUT.GALV..1/2}, conf = 0.46, lift = 1452.56, conv = 1.84
# {1-1/2".DWV.EL.45DEG.HXH} -> {1-1/2".DWV.EL.90DEG.HXH}, conf = 0.46, lift = 609.14, conv = 1.84
# {1/2".COP.TEE.CXCXC} -> {1/2".COP.EL.90.DEG.CXC}, conf = 0.45, lift = 532.88, conv = 1.83
# {50'.DISH.FOAM.ROLL} -> {SMALL.BOX.16"X12"X12"}, conf = 0.45, lift = 162.47, conv = 1.82
# {CUT.WASHERS.1/2.IN} -> {HEX.NUTS-USS.1/2}, conf = 0.45, lift = 833.86, conv = 1.81
# {M916.SEMI-RIGD.DRYER.DUCT, M934-DRYER.POWER.CORD} -> {M925-2.UPGRADE.STNLESS.WASHER.HOSE}, conf = 0.45, lift = 431.93, conv = 1.80
# {1/2".PVC.TEE.SXSXS} -> {1/2.X10.PVC40.PE.PIPE}, conf = 0.45, lift = 353.14, conv = 1.80
# {3/4".PVC.COUPLING.SXS, 3/4".PVC.MALE.ADAPTER.SXMPT} -> {3/4".PVC.EL.90D.SXS}, conf = 0.44, lift = 249.62, conv = 1.80
# {1".PVC.MALE.ADAPTER.SXMPT} -> {1".PVC.COUPLING.SXS}, conf = 0.44, lift = 329.44, conv = 1.79
# {1".PVC.TEE.SXSXS} -> {1".PVC.COUPLING.SXS}, conf = 0.44, lift = 328.48, conv = 1.79
# {3/4".PVC.TEE.SXSXS, 3/4.X.10.PVC40.PE.PIPE} -> {3/4".PVC.COUPLING.SXS}, conf = 0.44, lift = 188.39, conv = 1.79
# {HEAVY.DUTY.SMALL.BOX.16"X12"X12"} -> {MEDIUM.BOX.18"X18"X16}, conf = 0.44, lift = 124.31, conv = 1.78
# {1"X2'.PVC.PIPE} -> {1".PVC.COUPLING.SXS}, conf = 0.44, lift = 327.14, conv = 1.78
# {VEGETABLE.PEAT.POT.GROWUMS.4IN} -> {E/O.ECO.VEG.4.IN.PEAT.SHORT}, conf = 0.44, lift = 93.14, conv = 1.77
# {E/O.ECO.VEG.4.IN.PEAT.SHORT, E/O.VEGETABLE.1G.FIBER.POT.RED.BONN} -> {E/O.VEGETABLE.PEAT.POT.RED.5IN}, conf = 0.44, lift = 75.61, conv = 1.77
# {HEX.NUTS-USS.3/8} -> {CUT.WASHERS.3/8.IN}, conf = 0.44, lift = 480.05, conv = 1.78
# {3/4".PVC.EL.90D.SXS, 3/4".PVC.TEE.SXSXS} -> {3/4.X.10.PVC40.PE.PIPE}, conf = 0.44, lift = 248.34, conv = 1.77
# {2".DWV.EL.90DEG.HXH} -> {2X10.PVC40.PE.SOLIDCORE.PIPE}, conf = 0.43, lift = 556.57, conv = 1.76
# {E/O.ECO.VEG.4.IN.PEAT.SHORT} -> {E/O.VEGETABLE.PEAT.POT.RED.5IN}, conf = 0.43, lift = 74.79, conv = 1.75
# {M925-2.UPGRADE.STNLESS.WASHER.HOSE} -> {M916.SEMI-RIGD.DRYER.DUCT, M934-DRYER.POWER.CORD}, conf = 0.43, lift = 431.93, conv = 1.76
# {E/O.ECO.VEG.4.IN.PEAT.SHORT, VEGETABLE.VINES.4IN.(14.6OZ).PEAT} -> {E/O.BONNIE.ECO.PREM.PEATVEG.HERB.5IN}, conf = 0.43, lift = 55.15, conv = 1.74
# {LOCKWASHER.MED.SPLIT.1/4.ZINC} -> {HEX.NUTS-USS.1/4}, conf = 0.43, lift = 327.23, conv = 1.75
# {3/4".PVC.TEE.SXSXS} -> {3/4".PVC.COUPLING.SXS}, conf = 0.43, lift = 182.67, conv = 1.74
# {3/4".PVC.EL.45D.SXS} -> {3/4".PVC.COUPLING.SXS}, conf = 0.43, lift = 182.42, conv = 1.74
# {5/8".FEMALE.END.HOSE.REPAIR} -> {5/8".MALE.END.HOSE.REPAIR}, conf = 0.42, lift = 191.28, conv = 1.73
# {E/O.VEGETABLE.PEAT.POT.RED.5IN, VEGETABLE.VINES.4IN.(14.6OZ).PEAT} -> {E/O.BONNIE.ECO.PREM.PEATVEG.HERB.5IN}, conf = 0.42, lift = 54.28, conv = 1.72
# {3/4"X2'.PVC.PIPE} -> {3/4".PVC.COUPLING.SXS}, conf = 0.42, lift = 180.91, conv = 1.73
# {VEGETABLE.VINES.4IN.(14.6OZ).PEAT} -> {E/O.ECO.VEG.4.IN.PEAT.SHORT}, conf = 0.42, lift = 89.28, conv = 1.72
# {E/O.BONNIE.ECO.PREM.PEATVEG.HERB.5IN, E/O.VEGETABLE.1G.FIBER.POT.RED.BONN} -> {E/O.ECO.VEG.4.IN.PEAT.SHORT}, conf = 0.42, lift = 89.25, conv = 1.72
# {3/4".PVC.EL.45D.SXS} -> {3/4".PVC.EL.90D.SXS}, conf = 0.42, lift = 234.47, conv = 1.71
# {24"X24".70-SHEET.PACKING.PAPER} -> {SMALL.BOX.16"X12"X12"}, conf = 0.42, lift = 149.89, conv = 1.71
# {1/2".PVC.EL.90D.SXS, 1/2.X10.PVC40.PE.PIPE} -> {1/2".PVC.TEE.SXSXS}, conf = 0.42, lift = 627.60, conv = 1.71
# {1/2".PVC.EL.90D.SXS} -> {1/2.X10.PVC40.PE.PIPE}, conf = 0.41, lift = 326.16, conv = 1.70
# {DIABLO.80.GRIT.CORNER.CAT/MOUSE.SHTS} -> {DIABLO.120GRIT.CORNER.CAT/MOUSE.SHTS}, conf = 0.41, lift = 792.24, conv = 1.70
# {MOVING.&STORAGE.TAPE.1.88X109} -> {MEDIUM.BOX.18"X18"X16}, conf = 0.41, lift = 115.84, conv = 1.69
# {50'.DISH.FOAM.ROLL} -> {24"X24".70-SHEET.PACKING.PAPER}, conf = 0.41, lift = 322.70, conv = 1.70
# {CUT.WASHERS.1/4.IN} -> {HEX.NUTS-USS.1/4}, conf = 0.41, lift = 312.53, conv = 1.69
# {E/O.HERBS.1G.FIBER.POT.GREEN.BONNIE, E/O.VEGETABLE.1G.FIBER.POT.RED.BONN} -> {E/O.BONNIE.ECO.PREM.PEATVEG.HERB.5IN}, conf = 0.41, lift = 52.19, conv = 1.68
# {EXTRA.LARGE.BOX.22"X22"X21"} -> {MEDIUM.BOX.18"X18"X16}, conf = 0.41, lift = 114.71, conv = 1.68
# {M934-DRYER.POWER.CORD} -> {M925-2.UPGRADE.STNLESS.WASHER.HOSE}, conf = 0.41, lift = 394.39, conv = 1.68
# {1X10.PVC40.PE.PIPE} -> {1".PVC.EL.90D.SXS}, conf = 0.41, lift = 420.01, conv = 1.68
# {M916.SEMI-RIGD.DRYER.DUCT} -> {M925-2.UPGRADE.STNLESS.WASHER.HOSE}, conf = 0.41, lift = 392.93, conv = 1.68
# {E/O.ECO.VEG.4.IN.PEAT.SHORT, E/O.VEGETABLE.PEAT.POT.RED.5IN} -> {E/O.BONNIE.ECO.PREM.PEATVEG.HERB.5IN}, conf = 0.41, lift = 51.86, conv = 1.67
# {FLAT.CUT.WASHER.GALV..3/8} -> {HEX.NUT.GALV..3/8}, conf = 0.40, lift = 1204.99, conv = 1.67
# {1/2".COP.COUPLING.W/STOP.CXC} -> {1/2".COP.EL.90.DEG.CXC}, conf = 0.40, lift = 470.03, conv = 1.67
# {E/O.BONNIE.EXCLUSIVE.VEGGIE.3IN.PEAT} -> {E/O.VEGETABLE.PEAT.POT.RED.5IN}, conf = 0.40, lift = 69.04, conv = 1.66
# {VEGETABLE.VINES.4IN.(14.6OZ).PEAT} -> {E/O.VEGETABLE.PEAT.POT.RED.5IN}, conf = 0.40, lift = 68.79, conv = 1.65
# {24"X24".70-SHEET.PACKING.PAPER, SMALL.BOX.16"X12"X12"} -> {LARGE.BOX.18"X18"X24"}, conf = 0.40, lift = 173.87, conv = 1.66
# {1/2".COP.EL.90.DEG.CXC} -> {1/2".COP.COUPLING.W/STOP.CXC}, conf = 0.40, lift = 470.03, conv = 1.66
# {BEST.4.X.3/8.IN.NAP.WOV.ROLL.W.FRAME} -> {BEST.4.X.3/8.IN.WOVEN.ROLLER.2PK}, conf = 0.40, lift = 258.93, conv = 1.66
# {E/O.BONNIE.ECO.PREM.PEATVEG.HERB.5IN, E/O.HERBS.1G.FIBER.POT.GREEN.BONNIE} -> {E/O.VEGETABLE.PEAT.POT.RED.5IN}, conf = 0.39, lift = 68.13, conv = 1.64
# {3/4".PVC.COUPLING.SXS} -> {3/4".PVC.EL.90D.SXS}, conf = 0.39, lift = 221.47, conv = 1.65
# {ELBOW.1/2".SCH40.90DEG.BELL.END} -> {COUPLING.1/2"}, conf = 0.39, lift = 1403.33, conv = 1.64
# {3/4".PVC.COUPLING.SXS, 3/4".PVC.TEE.SXSXS} -> {3/4.X.10.PVC40.PE.PIPE}, conf = 0.39, lift = 221.83, conv = 1.64
# {ANNUAL.BEDDING.PLANT..96PT(.45L).BN} -> {ANNUAL.1.4QT.(1.32L).BN}, conf = 0.39, lift = 311.27, conv = 1.63
# {1/2".PVC.EL.90D.SXS} -> {1/2".PVC.COUPLING.SXS}, conf = 0.39, lift = 361.69, conv = 1.63
# {3/4"X1/2".PVC.EL.90D.SXFPT} -> {3/4".PVC.COUPLING.SXS}, conf = 0.39, lift = 165.79, conv = 1.63
# {1/2"X2'.PVC.PIPE} -> {1/2".PVC.COUPLING.SXS}, conf = 0.39, lift = 361.09, conv = 1.63
# {3/4".PVC.EL.90D.SXS, 3/4".PVC.MALE.ADAPTER.SXMPT} -> {3/4".PVC.TEE.SXSXS}, conf = 0.39, lift = 356.69, conv = 1.63
# {SCOTTS.TURF.BUILDER.PLUS.HALTS.15M} -> {ORTHO.WEED.B.GON.+.CRBGRSS.1.GAL.RTU}, conf = 0.39, lift = 302.53, conv = 1.63
# {3/4".PVC.EL.90D.SXS, 3/4.X.10.PVC40.PE.PIPE} -> {3/4".PVC.TEE.SXSXS}, conf = 0.39, lift = 356.03, conv = 1.63
# {E/O.VEGETABLE.1G.FIBER.POT.RED.BONN, E/O.VEGETABLE.PEAT.POT.RED.5IN} -> {E/O.ECO.VEG.4.IN.PEAT.SHORT}, conf = 0.39, lift = 82.11, conv = 1.62
# {E/O.BONNIE.ECO.PREM.PEATVEG.HERB.5IN, E/O.VEGETABLE.1G.FIBER.POT.RED.BONN} -> {E/O.VEGETABLE.PEAT.POT.RED.5IN}, conf = 0.39, lift = 66.72, conv = 1.62
# {E/O.VEGETABLE.1G.FIBER.POT.RED.BONN, E/O.VEGETABLE.PEAT.POT.RED.5IN} -> {E/O.BONNIE.ECO.PREM.PEATVEG.HERB.5IN}, conf = 0.39, lift = 49.46, conv = 1.62
# {1/2".PVC.COUPLING.SXS} -> {1/2".PVC.EL.90D.SXS}, conf = 0.38, lift = 361.69, conv = 1.62
# {VEGETABLE.VINE.12-04PK.BP} -> {E/O.ECO.VEG.4.IN.PEAT.SHORT}, conf = 0.38, lift = 80.81, conv = 1.61
# {3/4".PVC.FEMALE.ADAPTER.SXFPT} -> {3/4".PVC.MALE.ADAPTER.SXMPT}, conf = 0.38, lift = 244.74, conv = 1.61
# {SL.EDGER.PRO} -> {SL.CORNER.PAINTER./.EDGER.REFILL}, conf = 0.38, lift = 286.65, conv = 1.61
# {3/4".PVC.TEE.SXSXS} -> {3/4.X.10.PVC40.PE.PIPE}, conf = 0.38, lift = 215.09, conv = 1.60
# {MEDIUM.BOX.18"X18"X16} -> {LARGE.BOX.18"X18"X24"}, conf = 0.38, lift = 165.05, conv = 1.60
# {E/O.BONNIE.ECO.PREM.PEATVEG.HERB.5IN, E/O.HERBS.1G.FIBER.POT.GREEN.BONNIE} -> {E/O.ECO.VEG.4.IN.PEAT.SHORT}, conf = 0.38, lift = 80.12, conv = 1.60
# {VEGETABLE.PEAT.POT.GROWUMS.4IN} -> {E/O.BONNIE.ECO.PREM.PEATVEG.HERB.5IN}, conf = 0.38, lift = 48.22, conv = 1.59
# {2".DWV.COUPLING.HXH} -> {2".DWV.EL.90DEG.HXH}, conf = 0.38, lift = 693.07, conv = 1.60
# {3/4"X1/2".PVC.EL.90D.SXFPT} -> {3/4.X.10.PVC40.PE.PIPE}, conf = 0.38, lift = 214.35, conv = 1.60
# {1-1/2".PVC.EL.90D.SXS} -> {1-1/2".PVC.COUPLING.SXS}, conf = 0.38, lift = 367.65, conv = 1.60
# {1-1/2".PVC.EL.90D.SXS} -> {1-1/2X10.PVC40.PE.SOLIDCORE.PIPE}, conf = 0.38, lift = 323.61, conv = 1.60
# {SCOTCH.MOVING.&.STORAGE.TAPE.2X22} -> {SMALL.BOX.16"X12"X12"}, conf = 0.38, lift = 134.78, conv = 1.60
# {3/4".PVC.COUPLING.SXS, 3/4".PVC.EL.90D.SXS} -> {3/4.X.10.PVC40.PE.PIPE}, conf = 0.37, lift = 212.12, conv = 1.59
# {3/4"X1/2".PVC.TEE.SXSXFPT} -> {3/4".PVC.COUPLING.SXS}, conf = 0.37, lift = 158.89, conv = 1.59
# {3/16"X12"X100'.BUBBLE.CUSHION.WRAP} -> {MEDIUM.BOX.18"X18"X16}, conf = 0.37, lift = 104.85, conv = 1.59
# {M934-DRYER.POWER.CORD} -> {M916.SEMI-RIGD.DRYER.DUCT, M925-2.UPGRADE.STNLESS.WASHER.HOSE}, conf = 0.37, lift = 700.13, conv = 1.59
# {CACTUS.SUCCULENT.1.PINT} -> {CACTUS.SUCCULENT.3IN}, conf = 0.37, lift = 427.66, conv = 1.59
# {VEGETABLE.PEPPER.12.04.PK-BP} -> {E/O.VEGETABLE.PEAT.POT.RED.5IN}, conf = 0.37, lift = 63.86, conv = 1.58
# {E/O.VEGETABLE.PEAT.POT.RED.4IN} -> {E/O.BONNIE.ECO.PREM.PEATVEG.HERB.5IN}, conf = 0.37, lift = 47.24, conv = 1.57
# {E/O.HERBS.1G.FIBER.POT.GREEN.BONNIE} -> {E/O.BONNIE.ECO.PREM.PEATVEG.HERB.5IN}, conf = 0.37, lift = 47.20, conv = 1.57
# {HEX.NUTS-USS.5/16} -> {CUT.WASHERS.5/16.IN}, conf = 0.37, lift = 406.54, conv = 1.58
# {E/O.BONNIE.EXCLUSIVE.VEGGIE.3IN.PEAT} -> {E/O.ECO.VEG.4.IN.PEAT.SHORT}, conf = 0.36, lift = 77.47, conv = 1.57
# {1/2".X.4".RISER} -> {1/2".X.2".RISER}, conf = 0.36, lift = 529.88, conv = 1.57
# {3/4.X.10.PVC40.PE.PIPE} -> {3/4".PVC.EL.90D.SXS}, conf = 0.36, lift = 204.59, conv = 1.57
# {HEX.NUTS-USS.1/4} -> {CUT.WASHERS.1/4.IN}, conf = 0.36, lift = 312.53, conv = 1.57
# {2G.WHT.MIDWAY.SWITCH.WALLPLT} -> {1G.WHT.MIDWAY.SWITCH.WALLPLT}, conf = 0.36, lift = 274.56, conv = 1.57
# {1".PVC.EL.90D.SXS} -> {1X10.PVC40.PE.PIPE}, conf = 0.36, lift = 420.01, conv = 1.57
# {VEGETABLE.COLE.CROP.12-04PK-BP} -> {E/O.BONNIE.ECO.PREM.PEATVEG.HERB.5IN}, conf = 0.36, lift = 46.32, conv = 1.56
# {E/O.VEGETABLE.PEAT.POT.RED.4IN} -> {E/O.VEGETABLE.PEAT.POT.RED.5IN}, conf = 0.36, lift = 62.40, conv = 1.56
# {3/4".PVC.EL.90D.SXS} -> {3/4.X.10.PVC40.PE.PIPE}, conf = 0.36, lift = 204.59, conv = 1.56
# {ECON.3.X.3/8.IN.TRIM.ROLLER.W.FRAME} -> {ECON.3.X.3/8.IN.TRIM.ROLL.COV.2PK}, conf = 0.36, lift = 250.08, conv = 1.55
# {STEP.1.PAVER.BASE.SAND} -> {STEP.2.LEVELING.SAND}, conf = 0.36, lift = 221.92, conv = 1.55
# {FOAM.2.0.WOOD.HANDLE.BRUSH, FOAM.3.0.WOOD.HANDLE.BRUSH} -> {FOAM.1.0.WOOD.HANDLE.BRUSH}, conf = 0.36, lift = 138.58, conv = 1.55
# {BEHR.PPUI.203.DEEP.SAMPLE.8OZ} -> {BEHR.PPUI.204.MEDIUM.SAMPLE.8OZ}, conf = 0.36, lift = 129.04, conv = 1.55
# {2".DWV.EL.90DEG.HXH} -> {2".DWV.COUPLING.HXH}, conf = 0.36, lift = 693.07, conv = 1.55
# {MEDIUM.BOX.18"X18"X16, SMALL.BOX.16"X12"X12"} -> {LARGE.BOX.18"X18"X24"}, conf = 0.36, lift = 155.40, conv = 1.55
# {E/O.ECO.VEG.4.IN.PEAT.SHORT} -> {E/O.BONNIE.ECO.PREM.PEATVEG.HERB.5IN}, conf = 0.36, lift = 45.44, conv = 1.54
# {SCOTCH.MOVING.&.STORAGE.TAPE.3PK} -> {SMALL.BOX.16"X12"X12"}, conf = 0.35, lift = 127.35, conv = 1.54
# {1".PVC.COUPLING.SXS} -> {1".PVC.EL.90D.SXS}, conf = 0.35, lift = 366.85, conv = 1.55
# {EXTRA.LARGE.BOX.22"X22"X21"} -> {LARGE.BOX.18"X18"X24"}, conf = 0.35, lift = 154.75, conv = 1.54
# {CUT.WASHERS.5/16.IN} -> {HEX.NUTS-USS.5/16}, conf = 0.35, lift = 406.54, conv = 1.55
# {5/8".MALE.END.HOSE.REPAIR} -> {5/8".FEMALE.END.HOSE.REPAIR}, conf = 0.35, lift = 191.28, conv = 1.54
# {ANNUAL.PREMIUM.4.5IN.BEDDING.PBF} -> {ANNUAL.4.5IN.BEDDING.PBF}, conf = 0.35, lift = 188.28, conv = 1.54
# {SCOTCH.MOVING.&.STORAGE.TAPE.2X22} -> {MEDIUM.BOX.18"X18"X16}, conf = 0.35, lift = 99.26, conv = 1.54
# {E/O.VEGETABLE.PEAT.POT.RED.5IN} -> {E/O.ECO.VEG.4.IN.PEAT.SHORT}, conf = 0.35, lift = 74.79, conv = 1.54
# {3/4".PVC.FEMALE.ADAPTER.SXFPT} -> {3/4".PVC.EL.90D.SXS}, conf = 0.35, lift = 197.62, conv = 1.54
# {M939-DISHWASHER.INST.KIT.&.ADAPTER} -> {M921.DISHWASHER.INSTALL, M936-DISHWASHER.110V.CORD}, conf = 0.35, lift = 882.03, conv = 1.54
# {3/4".PVC.MALE.ADAPTER.SXMPT} -> {3/4".PVC.COUPLING.SXS}, conf = 0.35, lift = 149.54, conv = 1.54
# {SCOTCH.MOVING.&.STORAGE.TAPE.W/.DISP} -> {SMALL.BOX.16"X12"X12"}, conf = 0.35, lift = 125.68, conv = 1.53
# {1".PVC.MALE.ADAPTER.SXMPT} -> {1".PVC.EL.90D.SXS}, conf = 0.35, lift = 361.46, conv = 1.53
# {VEGETABLE.TOMATO.120-04PK-BP} -> {E/O.ECO.VEG.4.IN.PEAT.SHORT}, conf = 0.35, lift = 73.97, conv = 1.53
# {1/2".PVC.MALE.ADAPTER.SXMPT} -> {1/2".PVC.EL.90D.SXS}, conf = 0.35, lift = 329.31, conv = 1.53
# {BEHR.PPUI.200.UPW.SAMPLE.8OZ, BEHR.PPUI.204.MEDIUM.SAMPLE.8OZ} -> {BEHR.PPUI.203.DEEP.SAMPLE.8OZ}, conf = 0.35, lift = 139.54, conv = 1.53
# {VEGETABLE.VINE.12-04PK.BP} -> {E/O.VEGETABLE.PEAT.POT.RED.5IN}, conf = 0.35, lift = 60.03, conv = 1.52
# {VEGETABLE.VINE.12-04PK.BP} -> {E/O.BONNIE.ECO.PREM.PEATVEG.HERB.5IN}, conf = 0.35, lift = 44.50, conv = 1.52
# {FOAM.1.0.WOOD.HANDLE.BRUSH} -> {FOAM.2.0.WOOD.HANDLE.BRUSH}, conf = 0.35, lift = 118.90, conv = 1.53
# {1/2.X10.PVC40.PE.PIPE} -> {1/2".PVC.EL.90D.SXS}, conf = 0.34, lift = 326.16, conv = 1.52
# {M916.SEMI-RIGD.DRYER.DUCT} -> {M925-2.UPGRADE.STNLESS.WASHER.HOSE, M934-DRYER.POWER.CORD}, conf = 0.34, lift = 697.55, conv = 1.52
# {3/4".PVC.COUPLING.SXS, 3/4".PVC.EL.90D.SXS} -> {3/4".PVC.TEE.SXSXS}, conf = 0.34, lift = 312.84, conv = 1.51
# {SCOTCH.MOVING.&.STORAGE.TAPE.3PK} -> {LARGE.BOX.18"X18"X24"}, conf = 0.34, lift = 148.02, conv = 1.51
# {24"X24".70-SHEET.PACKING.PAPER} -> {MEDIUM.BOX.18"X18"X16, SMALL.BOX.16"X12"X12"}, conf = 0.34, lift = 185.22, conv = 1.50
# {VEGETABLE.COLE.CROP.12-04PK-BP} -> {E/O.VEGETABLE.PEAT.POT.RED.5IN}, conf = 0.34, lift = 58.03, conv = 1.50
# {WHITE.PRELOADED.BACK.WALL.CLIPS.7PK} -> {12".WHT.SHELVNG.SUPPORT.BRACKETS.2PK}, conf = 0.33, lift = 511.38, conv = 1.50
# {1/2".X.CLOSE.RISER} -> {1/2".X.2".RISER}, conf = 0.33, lift = 484.46, conv = 1.50
# {3/4".PVC.COUPLING.SXS, 3/4.X.10.PVC40.PE.PIPE} -> {3/4".PVC.TEE.SXSXS}, conf = 0.33, lift = 306.83, conv = 1.50
# {3/4".PVC.FEMALE.ADAPTER.SXFPT} -> {3/4".PVC.COUPLING.SXS}, conf = 0.33, lift = 142.34, conv = 1.50
# {1-1/2".DWV.EL.90DEG.HXH} -> {1-1/2"X2'.PVC-PW/DWV.SCH40.PIPE}, conf = 0.33, lift = 302.67, conv = 1.49
# {CHIP.3.0.FLAT.BRUSH} -> {CHIP.2.0.FLAT.BRUSH}, conf = 0.33, lift = 74.39, conv = 1.49
# {LARGE.BOX.18"X18"X24"} -> {SMALL.BOX.16"X12"X12"}, conf = 0.33, lift = 118.54, conv = 1.49
# {3/4".PVC.EL.90D.SXS, 3/4".PVC.TEE.SXSXS} -> {3/4".PVC.MALE.ADAPTER.SXMPT}, conf = 0.33, lift = 212.61, conv = 1.49
# {1X10.PVC40.PE.PIPE} -> {1".PVC.COUPLING.SXS}, conf = 0.33, lift = 244.20, conv = 1.49
# {BEHR.PPUI.203.DEEP.SAMPLE.8OZ, BEHR.PPUI.204.MEDIUM.SAMPLE.8OZ} -> {BEHR.PPUI.200.UPW.SAMPLE.8OZ}, conf = 0.33, lift = 114.38, conv = 1.48
# {1".PVC.TEE.SXSXS} -> {1".PVC.EL.90D.SXS, 1X10.PVC40.PE.PIPE}, conf = 0.33, lift = 932.17, conv = 1.48
# {FOAM.3.0.WOOD.HANDLE.BRUSH} -> {FOAM.2.0.WOOD.HANDLE.BRUSH}, conf = 0.33, lift = 111.69, conv = 1.48
# {1".PVC.EL.90D.SXS} -> {1".PVC.TEE.SXSXS}, conf = 0.33, lift = 566.82, conv = 1.48
# {1/2".X.2".RISER} -> {1/2".X.CLOSE.RISER}, conf = 0.32, lift = 484.46, conv = 1.48
# {SWIMMING.POOL.MURIATIC.ACID.2X1.GAL} -> {KEMKLOR.II.LIQUID.CHLORINE.2.GALLON}, conf = 0.32, lift = 272.56, conv = 1.48
# {1X10.PVC40.PE.PIPE} -> {1".PVC.TEE.SXSXS}, conf = 0.32, lift = 561.03, conv = 1.47
# {BEHR.PPUI.204.MEDIUM.SAMPLE.8OZ} -> {BEHR.PPUI.203.DEEP.SAMPLE.8OZ}, conf = 0.32, lift = 129.04, conv = 1.47
# {VEGETABLE.TOMATO.120-04PK-BP} -> {E/O.VEGETABLE.PEAT.POT.RED.5IN}, conf = 0.32, lift = 55.48, conv = 1.47
# {QT.3.X.1/4IN.TINY.TOUCH.UP.KIT.WOVEN} -> {QT.3.X.1/4.IN.TINY.TOUCH.UP.REFILL.-}, conf = 0.32, lift = 886.70, conv = 1.47
# {1/2".PVC.EL.90D.SXS} -> {1/2".PVC.TEE.SXSXS}, conf = 0.32, lift = 482.00, conv = 1.47
# {VEGETABLE.VINES.4IN.(14.6OZ).PEAT} -> {E/O.BONNIE.ECO.PREM.PEATVEG.HERB.5IN}, conf = 0.32, lift = 40.79, conv = 1.46
# {3/4".PVC.EL.90D.SXS} -> {3/4".PVC.TEE.SXSXS}, conf = 0.32, lift = 293.30, conv = 1.47
# {9IN..METAL.ROLLER.TRAY} -> {9.IN.PLASTIC.TRAY.LINER.-.WHITE}, conf = 0.31, lift = 50.75, conv = 1.45
# {TURF.BLDR.PLUS.HALTS.5000.SQ.FT/HOST} -> {ORTHO.WEED.B.GON.+.CRBGRSS.1.GAL.RTU}, conf = 0.31, lift = 243.66, conv = 1.45
# {E/O.VEGETABLE.PEAT.POT.RED.5IN} -> {E/O.BONNIE.ECO.PREM.PEATVEG.HERB.5IN}, conf = 0.31, lift = 39.85, conv = 1.44
# {3/4".PVC.MALE.ADAPTER.SXMPT} -> {3/4".PVC.EL.90D.SXS}, conf = 0.31, lift = 174.83, conv = 1.45
# {MOVING.&STORAGE.TAPE.1.88X109} -> {LARGE.BOX.18"X18"X24"}, conf = 0.31, lift = 136.01, conv = 1.45
# {CHIP.1.0.FLAT.BRUSH} -> {CHIP.2.0.FLAT.BRUSH}, conf = 0.31, lift = 69.80, conv = 1.44
# {3/4.X.10.PVC40.PE.PIPE} -> {3/4".PVC.COUPLING.SXS}, conf = 0.31, lift = 132.07, conv = 1.44
# {VEGETABLE.PEAT.POT.GROWUMS.4IN} -> {E/O.ECO.VEG.4.IN.PEAT.SHORT, E/O.VEGETABLE.PEAT.POT.RED.5IN}, conf = 0.31, lift = 150.83, conv = 1.44
# {1/2".X.2".RISER} -> {1/2".X.4".RISER}, conf = 0.31, lift = 529.88, conv = 1.44
# {1-1/2".DWV.EL.90DEG.HXH} -> {1-1/2X10.PVC40.PE.SOLIDCORE.PIPE}, conf = 0.31, lift = 264.45, conv = 1.44
# {FOAM.2.0.WOOD.HANDLE.BRUSH} -> {FOAM.1.0.WOOD.HANDLE.BRUSH}, conf = 0.31, lift = 118.90, conv = 1.44
# {1/2".PVC.CAP.SLIP} -> {1/2".PVC.EL.90D.SXS}, conf = 0.31, lift = 289.83, conv = 1.44
# {1/2".PVC.CAP.SLIP} -> {1/2.X10.PVC40.PE.PIPE}, conf = 0.31, lift = 242.68, conv = 1.44
# {2X10.PVC40.PE.SOLIDCORE.PIPE} -> {2".DWV.EL.90DEG.HXH}, conf = 0.30, lift = 556.57, conv = 1.43
# {BEHR.PPUI.204.MEDIUM.SAMPLE.8OZ} -> {BEHR.PPUI.200.UPW.SAMPLE.8OZ}, conf = 0.30, lift = 105.78, conv = 1.43
# {EXTRA.LARGE.BOX.22"X22"X21"} -> {SMALL.BOX.16"X12"X12"}, conf = 0.30, lift = 108.14, conv = 1.43
# {1/2.SCHEDULE.40.X.10.FT} -> {COUPLING.1/2"}, conf = 0.30, lift = 1080.56, conv = 1.43
# {VEGETABLE.COLE.CROP.9PK.BONNIE} -> {E/O.BONNIE.ECO.PREM.PEATVEG.HERB.5IN}, conf = 0.30, lift = 38.38, conv = 1.42
# Time spent finding association rules = 0.01 second.

# %% [markdown]
# **Definitions**

# %% [markdown]
# support: % of transactions that contain that itemset.
# Example: {milk,bread,butter} is in 20% of transactions, support of 20%
#
# confidence: % of transactions containing first items lead to second
# Example: {bread, butter} => {milk} has a confidence of 100%, since all bread and butter transactions contain milk as well.
#
# Lift: observed support of X and were independent
# supp(X,Y) / supp(X)*supp(Y)
